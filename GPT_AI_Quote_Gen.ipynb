# %% [markdown]
# <a href="https://colab.research.google.com/github/bitanb1999/TalentSumoAI/blob/main/GPT_AI_Quote_Gen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 7.3 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 7.5 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 63.9 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 56.0 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 52.6 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=b0f2c3f3ffc010fb8548be65bad7c7e7471b095072829c14bd4e4940d9173f3a
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.5.1 pyyaml-6.0 sacremoses-0.0.53 tokenizers-0.12.1 transformers-4.18.0

# %%
#for reproducability
SEED = 34

#maximum number of words in output text
MAX_LEN = 20

# %% [markdown]
# ###I. Intro
# A language model is a machine learning model that can look at part of a sentence and predict the next word/sequence of words. Much like the autofill features on your iPhone/Android, GPT-2 is capable of next word prediction on a much larger and more sophisticated scale. For reference, the smallest available GPT-2 has 117 million parameters, whereas the largest one (invisible to the public) has over 1.5 billion parameters. The largest one available for public use is half the size of their main GPT-2 model
#
# 😊 Transformers makes it very easy to import this model with both PyTorch and TensorFlow - in this notebook we will be using TensorFlow but it is just as easy in PyTorch. Both the model and its Tokenizer can be imported from the transformers library that anyone can get by typing !pip install transformers. Let's see just how simple it is to generate text with a neural network. We begin with our input sequence:

# %%
input_sequence = "All our dreams can come true"

# %%
#get transformers
from transformers import AutoModelWithLMHead, AutoTokenizer

#get large GPT2 tokenizer and GPT2 model
tokenizer = AutoTokenizer.from_pretrained("nandinib1999/quote-generator")
GPT2 = AutoModelWithLMHead.from_pretrained("nandinib1999/quote-generator", pad_token_id=tokenizer.eos_token_id)
GPT2
# Out:
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/666 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/96.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/auto/modeling_auto.py:911: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   FutureWarning,
# Downloading:   0%|          | 0.00/487M [00:00<?, ?B/s]
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50260, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50260, bias=False)
# )

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/nandinib1999/quote-generator"
headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()
	
output = query({
	"inputs": "All our dreams can come true",
})
output
# Out:
# {'error': 'Model nandinib1999/quote-generator is currently loading',
#  'estimated_time': 20.416631}

# %%
from transformers import pipeline
generator = pipeline('text-generation',
                     model='huggingtweets/greatestquotes')
generator("Choose a job", num_return_sequences=30)
# Out:
# Downloading:   0%|          | 0.00/790 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/487M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/357 [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Choose a job you love and enjoy doing. - Jim Rohn'},
#  {'generated_text': 'Choose a job that pays the best for you, not just the worst. - Les Brown'},
#  {'generated_text': 'Choose a job you love, study hard and you will make a living. Learn from failure and grow as a person. - Muhammad Ali'},
#  {'generated_text': 'Choose a job you love, work hard, and be happy. - Roger Babson'},
#  {'generated_text': 'Choose a job where you feel comfortable working. - Jim Rohn'},
#  {'generated_text': 'Choose a job you love, not one that you hate. - Mark Twain'},
#  {'generated_text': 'Choose a job you love, and you will never have to live a miserable life in your dreams. - Mark Twain'},
#  {'generated_text': 'Choose a job within your power to accomplish, not limit yourself by your abilities or talents." - Richard Bach'},
#  {'generated_text': 'Choose a job and you will get a good education. - Anthony Robbins'},
#  {'generated_text': 'Choose a job where you love your life, not your enemies. - William Arthur Ward'},
#  {'generated_text': 'Choose a job you love, spend your life doing it." - Oprah Winfrey'},
#  {'generated_text': 'Choose a job with a friend. A friend is someone who knows all about you. A friend is someone who listens to you and appreciates what you have to say. - Oprah Winfrey'},
#  {'generated_text': "Choose a job that offers you something, if at all. You'll find a way. - Charles F. Kettering"},
#  {'generated_text': "Choose a job that offers something to everyone, whether that's a good job or not. - David Henry Thoreau"},
#  {'generated_text': 'Choose a job with the right people. - Steve Jobs'},
#  {'generated_text': 'Choose a job you love. Learn a lesson every time you lose. - Walt Disney'},
#  {'generated_text': 'Choose a job, be a part of something great." - Mahatma Gandhi'},
#  {'generated_text': "Choose a job you love and don't have to change it. - Marianne Williamson"},
#  {'generated_text': 'Choose a job, start a business, find a way to live the life you\'ve imagined." - Mary Kay Ash'},
#  {'generated_text': "Choose a job you love that pays great people well, and those who don't love people don't get to do the hard work. - John Ruskin"},
#  {'generated_text': 'Choose a job that will give you an advantage over others. - Ralph Waldo Emerson'},
#  {'generated_text': 'Choose a job that pays the best for you, and prepare yourself for it. - William James #quote'},
#  {'generated_text': 'Choose a job you love, work hard, and be a champion. - Lao Tsu'},
#  {'generated_text': 'Choose a job, find time to do it, and then complain. - Anthony Robbins'},
#  {'generated_text': 'Choose a job that pays well and you get the full value for your investment. - Jim Rohn'},
#  {'generated_text': 'Choose a job you love, and you will live to be 30. - Tom Peters'},
#  {'generated_text': 'Choose a job that will let you do all things well, not least of which is to do something wonderful about your life. - John Keats #quote'},
#  {'generated_text': 'Choose a job where you can do it, and be sure you do it right." - Andy Warhol'},
#  {'generated_text': 'Choose a job or life. - Ralph Waldo Emerson'},
#  {'generated_text': 'Choose a job you love and you will make a life worth living. ~ Les Brown'}]

# %%
import tensorflow as tf
from transformers import GPT2LMHeadModel, GPT2Tokenizer #importing the main model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2-large")
model = GPT2LMHeadModel.from_pretrained("gpt2-large", pad_token_id=tokenizer.eos_token_id)
sentence = 'Career motivation' #input sentence
input_ids = tokenizer.encode(sentence, return_tensors='pt')
output = model.generate(input_ids, max_length=15, num_beams=5, no_repeat_ngram_size=2, early_stopping=True)
print(tokenizer.decode(output[0], skip_special_tokens=True))#printing results
output = model.generate(input_ids, max_length=20, num_beams=5, no_repeat_ngram_size=2, early_stopping=True) #setting length as 500 to generate larger output text
# Out:
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/666 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.02G [00:00<?, ?B/s]
# Career motivation is one of the most important things you can do for your

# %%
print(tokenizer.decode(output[0], skip_special_tokens=True))
text = tokenizer.decode(output[0],skip_special_tokens = True)
with open('AIBLOG.txt','w') as f:
  f.write(text)
# Out:
# Career motivation is one of the most important things you can do to improve your game.

# %%
beam_outputs = model.generate(
    input_ids, 
    max_length = 20, 
    num_beams = 20, 
    temperature = .7,
    no_repeat_ngram_size = 2, 
    num_return_sequences = 20, 
    early_stopping = True
)

print('')
print("Output:\n" + 100 * '-')

# now we have 3 output sequences
for i, beam_output in enumerate(beam_outputs):
      print("{}: {}".format(i, tokenizer.decode(beam_output, skip_special_tokens=True)))
# Out:
# Output:
# ----------------------------------------------------------------------------------------------------
# 0: Career motivation is one of the most important things you can do to improve your game.
#
#
# 1: Career motivation is one of the most important things you can do for yourself and for your career.
# 2: Career motivation is one of the best things you can do for yourself and your career.
#
#
# 3: Career motivation is one of the most important things you can do to improve your performance.
#
#
# 4: Career motivation is one of the most important things you can do for yourself and your career.
#
# 5: Career motivation is one of the most important things you can do to improve your life.
#
#
# 6: Career motivation is one of the most important things you can do for yourself and for your team.
# 7: Career motivation is one of the most important things you can do for yourself and your career. It
# 8: Career motivation is one of the most important things you can do for yourself. If you want to
# 9: Career motivation is one of the most important things you can do to improve your game. If you
# 10: Career motivation is one of the most important things you can do to improve your game. It's
# 11: Career motivation is one of the most important things you can do for yourself and your career. You
# 12: Career motivation is one of the most important things you can do for yourself and your career. If
# 13: Career motivation is one of the best things you can do for yourself and your career. It's
# 14: Career motivation is one of the most important things you can do to improve your performance. It's
# 15: Career motivation is one of the most important things you can do for yourself and your career. The
# 16: Career motivation is one of the most important things you can do for yourself. If you're not
# 17: Career motivation is one of the most important things you can do to improve your life. It's
# 18: Career motivation is one of the most important things you can do to improve your game. It is
# 19: Career motivation is one of the most important things you can do for your career.
#
# It

# %%
#combine both sampling techniques
sample_outputs = model.generate(
                              input_ids,
                              do_sample = True, 
                              max_length = 30,                              #to test how long we can generate and it be coherent
                              temperature = .9,
                              top_k = 50, 
                              top_p = 0.85, 
                              num_return_sequences = 5
)

print("Output:\n" + 100 * '-')
for i, sample_output in enumerate(sample_outputs):
    print("{}: {}...".format(i, tokenizer.decode(sample_output, skip_special_tokens = True)))
    print('')
# Out:
# Output:
# ----------------------------------------------------------------------------------------------------
# 0: Career motivation is a big factor in how effective your performance will be.
#
# "You have to find the most efficient ways of getting the most...
#
# 1: Career motivation to develop your own skills
#
# Developing a strong interest in your chosen subject
#
# Attention to detail
#
# Strong interpersonal skills...
#
# 2: Career motivation is not necessarily a factor in your success.
#
# Don't Be Afraid to Change
#
# There's nothing wrong with being scared...
#
# 3: Career motivation is a term used to describe a person's motivation for pursuing a career. This motivation may be a direct result of the individual's life...
#
# 4: Career motivation" in the work of the "Greats", who are supposed to be "the greatest of all time".
#
# It was never...

# %%
li=['Choose a job','Dream high','Your goals','Career is']
ar=[];
k=0;
quo={};
for i in li:
  ar=generator(i, num_return_sequences=10)
  for i in ar:
    val=[i[k] for k in i]
    quo[k]=val[0];
    k=k+1;
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
quotes=pd.DataFrame(quo.items(), columns=['Index', 'Quotes']).set_index('Index')
quotes.to_csv('Quotes.csv')

# %%
# !pip install PyQt5 nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 8.4 MB 27.3 MB/s
# ...
#      |████████████████████████████████| 59.9 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 344 kB 52.6 MB/s
# ...

# %%
# !pip install scrapy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 264 kB 28.4 MB/s
# ...
#      |████████████████████████████████| 251 kB 73.6 MB/s
# ...
#      |████████████████████████████████| 47 kB 6.5 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 58.2 MB/s
# ...
#      |████████████████████████████████| 93 kB 2.5 MB/s
# ...
#      |████████████████████████████████| 55 kB 4.9 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 71.2 MB/s
# ...
#      |████████████████████████████████| 74 kB 3.6 MB/s
# ...
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.5-py3-none-any.whl size=11516 sha256=7bb8ea7b9282075e64a1b4f207998cf629bae88c99f266df635bdbeed85d4acb
#   Stored in directory: /root/.cache/pip/wheels/2d/18/21/3c6a732eaa69a339198e08bb63b7da2c45933a3428b29ec454
# Successfully built PyDispatcher
# ...

# %%
# !pip install autoscraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install amfm_decompy aubio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 751 kB 21.7 MB/s
# ...
#      |████████████████████████████████| 479 kB 66.4 MB/s
# ...
#   Created wheel for amfm-decompy: filename=AMFM_decompy-1.0.11-py3-none-any.whl size=42848 sha256=cb683393f38aa0b8f00a5160399e5fc529257a2fe2badb24e9609d69e769255f
#   Stored in directory: /root/.cache/pip/wheels/a6/76/66/d51bd6c921a5842c5f22c9e0f59ed0735fbedd06a27d17f62e
# ...
#   Created wheel for aubio: filename=aubio-0.4.9-cp37-cp37m-linux_x86_64.whl size=390154 sha256=c7077bc830d5fbed053b832e7767fda4ada6aba0d5b710374af859dc435a6d4b
#   Stored in directory: /root/.cache/pip/wheels/82/d4/6a/930c11ef645b5c5b14e5152ea5030ab1d665593405ca3c5d3e
# Successfully built amfm-decompy aubio
# ...

# %%
# !pip install pitch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install librosa==0.6
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.5 MB 32.9 MB/s
# ...
#   Created wheel for librosa: filename=librosa-0.6.0-py3-none-any.whl size=1553494 sha256=52b5a69517ba9a5a22225019b919f98e32db21ed8b9eb87e5aefc10aad3b7bbf
#   Stored in directory: /root/.cache/pip/wheels/c3/b3/35/7d46f91ae587ddc98ef185534386c1830ed6773a93a8da085d
# Successfully built librosa
# ...
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.8.1
#     Uninstalling librosa-0.8.1:
#       Successfully uninstalled librosa-0.8.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kapre 0.3.7 requires librosa>=0.7.2, but you have librosa 0.6.0 which is incompatible.
# ...

# %%
# !pip install Wave moviepy SpeechRecognition
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 32.8 MB 1.2 MB/s
# ...
#   Created wheel for Wave: filename=Wave-0.0.2-py3-none-any.whl size=1240 sha256=630a0cc7b2dc6eb6226fc90ff0b0efb33ba832392272a5b6253157d5110b17cf
#   Stored in directory: /root/.cache/pip/wheels/25/e8/fe/458c7dac00c6abedad6380b9d0ef1a5cbc7c21807df1d30915
# Successfully built Wave
# ...

# %%
import urllib.request
url_link='https://talentsumo.click/Interview_Response/video_1655468025280.mp4'
urllib.request.urlretrieve(url_link, 'video_1655468025280.mp4')
# Out:
# ('video_1655468025280.mp4', <http.client.HTTPMessage at 0x7fee02e15290>)

# %%
#downloading the files
import requests
def download_video_series(video_links): 

  for link in video_links: 

      '''iterate through all links in video_links 
      and download them one by one'''

      # obtain filename by splitting url and getting  
      # last string 
      file_name = link.split('/')[-1]    

      print ("Downloading file:%s"%file_name)

      # create response object 
      r = requests.get(link, stream = True) 

      # download started 
      with open(file_name, 'wb') as f: 
          for chunk in r.iter_content(chunk_size = 1024*1024): 
              if chunk: 
                  f.write(chunk) 

      print ("%s downloaded!\n"%file_name)

  print ("All videos downloaded!")
  return

# %%
import numpy as np # linear algebra
import pandas as pd
import wave, math, contextlib
import speech_recognition as sr
from moviepy.editor import AudioFileClip
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.

# %%
transcribed_audio_file_name = "transcribed_speech.wav"
zoom_video_file_name = "/content/Answer 6.mp4"
audioclip = AudioFileClip(zoom_video_file_name)
audioclip.write_audiofile(transcribed_audio_file_name)
with contextlib.closing(wave.open(transcribed_audio_file_name,'r')) as f:
    frames = f.getnframes()
    rate = f.getframerate()
    duration = frames / float(rate)
total_duration = math.ceil(duration / 60)
r = sr.Recognizer()
def startConvertion(path = 'sample.wav',lang = 'en-IN'):
    with sr.AudioFile(path) as source:
        print('Fetching File')
        audio_text = r.listen(source,timeout=300, phrase_time_limit=300)
        # recoginize_() method will throw a request error if the API is unreachable, hence using exception handling
        try:
        
            # using google speech recognition
            print('Converting audio transcripts into text ...')
            text = r.recognize_google(audio_text)
            print(text)
            return text
    
        except:
            print('Sorry.. run again...')
# Out:
# [MoviePy] Writing audio in transcribed_speech.wav
# 100%|██████████| 1741/1741 [00:00<00:00, 2543.15it/s]
# [MoviePy] Done.

# %%
startConvertion(transcribed_audio_file_name)
# Out:
# Fetching File
# Converting audio transcripts into text ...
# ...

# %%
with open('transcription.txt', 'w') as f:
    print(f.write(startConvertion(transcribed_audio_file_name)))
# Out:
# Fetching File
# Converting audio transcripts into text ...
# ...

# %%
with open('transcription.txt', 'r') as f:
    text=f.read()

# %%
word_count_tex=len(text.split(" "))/(total_duration/2);
print("Words per minute are:",word_count_tex)
# Out:
# Words per minute are: 188.0

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
#print(stopwords.words('english'))
from nltk.tokenize import word_tokenize
stop_words = set(stopwords.words('english'))

word_tokens = word_tokenize(text)

filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]

filtered_sentence = []

for w in word_tokens:
	if w not in stop_words:
		filtered_sentence.append(w)

print(word_tokens)
print(filtered_sentence)
# Out:
# ['my', 'favorite', 'place', 'to', 'work', 'my', 'favorite', 'place', 'to', 'work', 'is', 'always', 'from', 'home', 'because', 'we', 'can', 'have', 'the', 'luxury', 'of', 'working', 'as', 'hard', 'as', 'we', 'want', 'or', 'for', 'that', 'matter', 'as', 'little', 'as', 'we', 'want', 'I', 'have', 'the', 'luxury', 'to', 'take', 'care', 'of', 'my', 'elderly', 'parents', 'as', 'well', 'as', 'contribute', 'to', 'the', 'household', 'chores', 'I', 'can', 'be', 'doubly', 'productive', 'because', 'I', 'know', 'that', 'I', 'have', 'a', 'limited', 'time', 'to', 'get', 'a', 'lot', 'done', 'and', 'I', 'can', 'also', 'contribute', 'at', 'the', 'same', 'time', 'to', 'multiple', 'projects', 'in', 'a', 'very', 'effective', 'manner', 'because', 'I', 'have', 'and', 'I', 'practiced', 'I', "'m", 'jumping', 'while', 'I', 'junk', 'my', 'times', 'for', 'different', 'perspectives', 'project', 'and', 'I', 'believe', 'in', 'the', 'modern', 'day', 'and', 'time', 'everybody', 'would', 'prefer', 'to', 'work', 'from
# ...

# %%
print(pd.Series(filtered_sentence).unique())
filtered_sentence_unique=pd.Series(filtered_sentence).unique()
# Out:
# ['favorite' 'place' 'work' 'always' 'home' 'luxury' 'working' 'hard'
#  'want' 'matter' 'little' 'I' 'take' 'care' 'elderly' 'parents' 'well'
#  'contribute' 'household' 'chores' 'doubly' 'productive' 'know' 'limited'
#  'time' 'get' 'lot' 'done' 'also' 'multiple' 'projects' 'effective'
#  'manner' 'practiced' "'m" 'jumping' 'junk' 'times' 'different'
#  'perspectives' 'project' 'believe' 'modern' 'day' 'everybody' 'would'
#  'prefer' 'unless' 'course' "'s" 'networking' 'event' 'really' 'network'
#  'meet' 'large' 'number' 'people' 'enjoy' 'events' 'even' 'situation'
#  'love' 'ask' 'normal' 'daily' 'stay' 'best' 'form']

# %%
from operator import itemgetter
import math
total_words = text.split()
total_word_length = len(total_words)
print(total_word_length)
# Out:
# 188

# %%
from nltk import tokenize
total_sentences = tokenize.sent_tokenize(text)
total_sent_len = len(total_sentences)
print(total_sent_len)
# Out:
# 1

# %%
tf_score = {}
for each_word in total_words:
    each_word = each_word.replace('.','')
    if each_word not in stop_words:
        if each_word in tf_score:
            tf_score[each_word] += 1
        else:
            tf_score[each_word] = 1

# Dividing by total_word_length for each dictionary element
tf_score.update((x, y/int(total_word_length)) for x, y in tf_score.items())
print(tf_score)
# Out:
# {'favorite': 0.010638297872340425, 'place': 0.010638297872340425, 'work': 0.026595744680851064, 'always': 0.005319148936170213, 'home': 0.015957446808510637, 'luxury': 0.010638297872340425, 'working': 0.010638297872340425, 'hard': 0.005319148936170213, 'want': 0.010638297872340425, 'matter': 0.005319148936170213, 'little': 0.005319148936170213, 'I': 0.06382978723404255, 'take': 0.005319148936170213, 'care': 0.005319148936170213, 'elderly': 0.005319148936170213, 'parents': 0.005319148936170213, 'well': 0.005319148936170213, 'contribute': 0.010638297872340425, 'household': 0.005319148936170213, 'chores': 0.005319148936170213, 'doubly': 0.005319148936170213, 'productive': 0.005319148936170213, 'know': 0.005319148936170213, 'limited': 0.005319148936170213, 'time': 0.015957446808510637, 'get': 0.005319148936170213, 'lot': 0.005319148936170213, 'done': 0.005319148936170213, 'also': 0.005319148936170213, 'multiple': 0.005319148936170213, 'projects': 0.005319148936170213, 'effective': 0.0053
# ...

# %%
def check_sent(word, sentences): 
    final = [all([w in x for w in word]) for x in sentences] 
    sent_len = [sentences[i] for i in range(0, len(final)) if final[i]]
    return int(len(sent_len))

# %%
idf_score = {}
for each_word in total_words:
    each_word = each_word.replace('.','')
    if each_word not in stop_words:
        if each_word in idf_score:
            idf_score[each_word] = check_sent(each_word, total_sentences)
        else:
            idf_score[each_word] = 1

# Performing a log and divide
idf_score.update((x, math.log(int(total_sent_len)/y)) for x, y in idf_score.items())

print(idf_score)
# Out:
# {'favorite': 0.0, 'place': 0.0, 'work': 0.0, 'always': 0.0, 'home': 0.0, 'luxury': 0.0, 'working': 0.0, 'hard': 0.0, 'want': 0.0, 'matter': 0.0, 'little': 0.0, 'I': 0.0, 'take': 0.0, 'care': 0.0, 'elderly': 0.0, 'parents': 0.0, 'well': 0.0, 'contribute': 0.0, 'household': 0.0, 'chores': 0.0, 'doubly': 0.0, 'productive': 0.0, 'know': 0.0, 'limited': 0.0, 'time': 0.0, 'get': 0.0, 'lot': 0.0, 'done': 0.0, 'also': 0.0, 'multiple': 0.0, 'projects': 0.0, 'effective': 0.0, 'manner': 0.0, 'practiced': 0.0, "I'm": 0.0, 'jumping': 0.0, 'junk': 0.0, 'times': 0.0, 'different': 0.0, 'perspectives': 0.0, 'project': 0.0, 'believe': 0.0, 'modern': 0.0, 'day': 0.0, 'everybody': 0.0, 'would': 0.0, 'prefer': 0.0, 'unless': 0.0, 'course': 0.0, "there's": 0.0, 'networking': 0.0, 'event': 0.0, 'really': 0.0, 'network': 0.0, 'meet': 0.0, 'large': 0.0, 'number': 0.0, 'people': 0.0, 'enjoy': 0.0, 'events': 0.0, 'even': 0.0, 'situation': 0.0, 'love': 0.0, 'ask': 0.0, 'normal': 0.0, 'daily': 0.0, 'stay': 0.0, 
# ...

# %%
tf_idf_score = {key: tf_score[key] * idf_score.get(key, 0) for key in tf_score.keys()}
print(tf_idf_score)
# Out:
# {'favorite': 0.0, 'place': 0.0, 'work': 0.0, 'always': 0.0, 'home': 0.0, 'luxury': 0.0, 'working': 0.0, 'hard': 0.0, 'want': 0.0, 'matter': 0.0, 'little': 0.0, 'I': 0.0, 'take': 0.0, 'care': 0.0, 'elderly': 0.0, 'parents': 0.0, 'well': 0.0, 'contribute': 0.0, 'household': 0.0, 'chores': 0.0, 'doubly': 0.0, 'productive': 0.0, 'know': 0.0, 'limited': 0.0, 'time': 0.0, 'get': 0.0, 'lot': 0.0, 'done': 0.0, 'also': 0.0, 'multiple': 0.0, 'projects': 0.0, 'effective': 0.0, 'manner': 0.0, 'practiced': 0.0, "I'm": 0.0, 'jumping': 0.0, 'junk': 0.0, 'times': 0.0, 'different': 0.0, 'perspectives': 0.0, 'project': 0.0, 'believe': 0.0, 'modern': 0.0, 'day': 0.0, 'everybody': 0.0, 'would': 0.0, 'prefer': 0.0, 'unless': 0.0, 'course': 0.0, "there's": 0.0, 'networking': 0.0, 'event': 0.0, 'really': 0.0, 'network': 0.0, 'meet': 0.0, 'large': 0.0, 'number': 0.0, 'people': 0.0, 'enjoy': 0.0, 'events': 0.0, 'even': 0.0, 'situation': 0.0, 'love': 0.0, 'ask': 0.0, 'normal': 0.0, 'daily': 0.0, 'stay': 0.0, 
# ...

# %%
def get_top_n(dict_elem, n):
    result = dict(sorted(dict_elem.items(), key = itemgetter(1), reverse = True)[:n]) 
    return result

# %%
print(get_top_n(tf_idf_score, 5))
# Out:
# {'favorite': 0.0, 'place': 0.0, 'work': 0.0, 'always': 0.0, 'home': 0.0}

# %%
import matplotlib
import pandas
import wordcloud
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
comment_words = ''
stopwords = set(STOPWORDS)

# split the value
tokens = filtered_sentence_unique

# Converts each token into lowercase
for i in range(len(tokens)):
    tokens[i] = tokens[i].lower()

    comment_words += " ".join(tokens)+" "

    wordcloud = WordCloud(width = 800, height = 800,background_color ='white',stopwords = stopwords,min_font_size= 10).generate(comment_words)
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
cou=0;
for j in text:
  if j in filtered_sentence_unique:
      cou+=1;
cou=cou/total_duration
print('Power word density/min:',cou)
# Out:
# Power word density/min: 17.0

# %%
import librosa
import librosa.display
audio = transcribed_audio_file_name
x, sr = librosa.load(audio)
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize = (10, 5))
librosa.display.specshow(Xdb, sr = sr, x_axis = 'time', y_axis = 'hz')
plt.colorbar()

# %%
import sklearn
spectral_centroids = librosa.feature.spectral_centroid(x, sr = sr)[0]
#spectral_centroids.shape(775, )
# Computing the time variable
#for visualization
plt.figure(figsize = (12, 4))
frames = range(len(spectral_centroids))
t = librosa.frames_to_time(frames)
# Normalising the spectral centroid
#for visualisation
def normalize(x, axis = 0):
  return sklearn.preprocessing.minmax_scale(x, axis = axis)
#Plotting the Spectral Centroid along the waveform
librosa.display.waveplot(x, sr = sr, alpha = 0.4)
plt.plot(t, normalize(spectral_centroids), color = 'b')

# %%
spectral_rolloff = librosa.feature.spectral_rolloff(x + 0.01, sr = sr)[0]
plt.figure(figsize = (12, 4))
librosa.display.waveplot(x, sr = sr, alpha = 0.4)
plt.plot(t, normalize(spectral_rolloff), color = 'r')

# %%
spectral_bandwidth_2 = librosa.feature.spectral_bandwidth(x + 0.01, sr = sr)[0]
spectral_bandwidth_3 = librosa.feature.spectral_bandwidth(x + 0.01, sr = sr, p = 3)[0]
spectral_bandwidth_4 = librosa.feature.spectral_bandwidth(x + 0.01, sr = sr, p = 4)[0]
plt.figure(figsize = (15, 9))
librosa.display.waveplot(x, sr = sr, alpha = 0.4)
plt.plot(t, normalize(spectral_bandwidth_2), color = 'r')
plt.plot(t, normalize(spectral_bandwidth_3), color = 'g')
plt.plot(t, normalize(spectral_bandwidth_4), color = 'y')

# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
from scipy.signal import find_peaks
data, sampling_frequency = librosa.load(transcribed_audio_file_name)

# Get some useful statistics
T = 1/sampling_frequency # Sampling period
N = len(data) # Signal length in samples
t = N / sampling_frequency

# %%
Y_k = np.fft.fft(data)[0:int(N/2)]/N # FFT
Y_k[1:] = 2*Y_k[1:] # Single-sided spectrum
Pxx = np.abs(Y_k) # Power spectrum

f = sampling_frequency * np.arange((N/2)) / N; # frequencies

# plotting
fig,ax = plt.subplots()
plt.plot(f[0:5000], Pxx[0:5000], linewidth=2)
plt.ylabel('Amplitude')
plt.xlabel('Frequency [Hz]')
plt.show()

# %%
f[0:5000].sum()
# Out:
# 158356.5636087177

# %%
auto = sm.tsa.acf(data, nlags=2000)

# %%
peaks = find_peaks(auto)[0] # Find peaks of the autocorrelation
lag = peaks[0] # Choose the first peak as our pitch component lag

# %%
pitc=sampling_frequency / lag

# %%
pitc
# Out:
# 689.0625

# %%
# !pip install source
import amfm_decompy.basic_tools as basic
import amfm_decompy.pYAAPT as pYAAPT
import matplotlib.pyplot as plt
import aubio
# load audio
signal = basic.SignalObj(transcribed_audio_file_name)
filename = transcribed_audio_file_name
# YAAPT pitches 
pitchY = pYAAPT.yaapt(signal, frame_length=40, tda_frame_length=40, f0_min=75, f0_max=600)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# plot
fig, (ax1) = plt.subplots(1, 1, sharex=True, sharey=True, figsize=(12, 8))
ax1.plot(pitchY.samp_values, label='YAAPT', color='blue')
plt.show()

# %%
# !pip install -q transformers
from transformers import pipeline
classifier = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base", return_all_scores=True)
classifier(text)
# Out:
# Downloading:   0%|          | 0.00/0.98k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/313M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/294 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/780k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# [{'label': 'anger', 'score': 0.0034791380167007446},
#  {'label': 'disgust', 'score': 0.0006852465448901057},
#  {'label': 'fear', 'score': 0.0019279640400782228},
#  {'label': 'joy', 'score': 0.9780314564704895},
#  {'label': 'neutral', 'score': 0.0068212999030947685},
#  {'label': 'sadness', 'score': 0.004890849813818932},
#  {'label': 'surprise', 'score': 0.0041640568524599075}]

# %%
answer="From the research I've conducted, it appears your company operates in a collaborative environment that fosters professional advancement. This is my ideal working environment, as I thrive working as part of a team. I prefer working in a group where team members can encourage each other and share their ideas. I also enjoy working for a company where I know I can continue to grow my skills both personally and professionally."

# %%
# !pip install sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 79 kB 4.8 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 25.4 MB/s
# ...
#      |████████████████████████████████| 127 kB 53.9 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=9074dbc6be5a555e3c655b9f2217155f464331f268ee0596c6f6353b310946ae
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
# Successfully built sentence-transformers
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.9
#     Uninstalling urllib3-1.26.9:
#       Successfully uninstalled urllib3-1.26.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('bert-base-nli-mean-tokens')
# Out:
# Downloading:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.95k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/399 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
sentences=[answer,text]
sentence_embeddings = model.encode(sentences)

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity(
    [sentence_embeddings[0]],
    [sentence_embeddings[1]]
)
# Out:
# array([[0.71607053]], dtype=float32)

# %%
# !pip install gensim 
from gensim.summarization.summarizer import summarize
from gensim.summarization import keywords
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
coun=0
rev=''
for i in text.split(' '):
  rev=rev+i+" ";
  coun+=1
  if coun==10:
    rev=rev+'\n'+' '
    coun=0;
rev
# Out:
# "my favorite place to work my favorite place to work \n is always from home because we can have the luxury \n of working as hard as we want or for that \n matter as little as we want I have the luxury \n to take care of my elderly parents as well as \n contribute to the household chores I can be doubly productive \n because I know that I have a limited time to \n get a lot done and I can also contribute at \n the same time to multiple projects in a very effective \n manner because I have and I practiced I'm jumping while \n I junk my times for different perspectives project and I \n believe in the modern day and time everybody would prefer \n to work from home unless of course there's a networking \n event why we really have to network and meet a \n large number of people and and of course I enjoy \n such events and even work and I'm in that situation \n I would love to do that but if you ask \n me for a normal daily situation I would stay working \n from home is my best form of work
# ...

# %%
tex=summarize(rev, ratio=1.0)

# %%
ans=summarize(answer, ratio=1.0)

# %%
text_list = [tex,ans]
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
count_matrix = cv.fit_transform(text_list)

# %%
# get the match percentage
matchPercentage = cosine_similarity(count_matrix)[0][1] * 100
matchPercentage = round(matchPercentage, 2) # round to two decimal
print("Your answer matches about "+ str(matchPercentage)+ "% of the ideal answer.")
# output
print(keywords(text, ratio=0.70))
# Out:
# Your answer matches about 42.99% of the ideal answer.
# time
# times
# daily
# projects
# perspectives project
# best form
# favorite place
# elderly parents
# networking event
# events
# work
# working
# network
# effective manner
# stay
# large number
# doubly productive
# modern
